# %% [markdown]
# # Training A Flow (using in-built objects)

# %% [markdown]
# On this page, we provide more details on how to make your own Neural Posterior Estimator (NPE) using in-built data generation, embeddings and flows (i.e. `BilbyFlow` objects).

# %% [markdown]
# ## Outline

# %% [markdown]
# ## Downloading Off-Segment Data

# %% [markdown]
# ## Detailed Config Descriptions
